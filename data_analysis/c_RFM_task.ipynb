# %%
import pandas as pd

path = "./datasets/customer_shopping_data.csv"
customer_shopping_df = pd.read_csv(path)
customer_shopping_df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 1         Debit Card   12/12/2021    Forum Istanbul
# 2               Cash    9/11/2021         Metrocity
# 3        Credit Card   16/05/2021      Metropol AVM
# 4               Cash   24/10/2021            Kanyon
# ...              ...          ...               ...
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul
#
# [99457 rows x 10 columns]

# %%
customer_shopping_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %%
missing_values = customer_shopping_df.isnull().sum()
print(missing_values)
# Out:
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# category          0
# quantity          0
# price             0
# payment_method    0
# invoice_date      0
# shopping_mall     0
# dtype: int64

# %%
customer_shopping_df.duplicated().sum()
# Out:
# 0

# %%
customer_shopping_df['invoice_date'] = pd.to_datetime(customer_shopping_df['invoice_date'], dayfirst=True)
display(customer_shopping_df)
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall  Frequency  Monetary
# 0        Credit Card   2022-08-05            Kanyon          1   7502.00
# 1         Debit Card   2021-12-12    Forum Istanbul          1   5401.53
# 2               Cash   2021-11-09         Metrocity          1    300.08
# 3        Credit Card   2021-05-16      Metropol AVM          1  15004.25
# 4               Cash   2021-10-24            Kanyon          1    242.40
# ...              ...          ...               ...        ...       ...
# 99452    Credit Card   2022-09-21            Kanyon          1    293.25
# 99453           Cash   2021-09-22    Forum Istanbul          1     20.92
# 99454     Debit Card   2021-03-28         Metrocity          1     20.92
# 99455           Cash   2021-03-16      Istinye Park          1  16800.00
# 99456    Credit Card   2022-10-15  Mall of Istanbul          1    105.57
#
# [99457 rows x 12 columns]

# %%
current_date = '2023-10-04'
current_datetime = pd.to_datetime(current_date)
recency = current_datetime - customer_shopping_df['invoice_date']
customer_shopping_df['Recency'] = recency.dt.days
display(customer_shopping_df)
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall  Frequency  Monetary  \
# 0        Credit Card   2022-08-05            Kanyon          1   7502.00
# 1         Debit Card   2021-12-12    Forum Istanbul          1   5401.53
# 2               Cash   2021-11-09         Metrocity          1    300.08
# 3        Credit Card   2021-05-16      Metropol AVM          1  15004.25
# 4               Cash   2021-10-24            Kanyon          1    242.40
# ...              ...          ...               ...        ...       ...
# 99452    Credit Card   2022-09-21            Kanyon          1    293.25
# 99453           Cash   2021-09-22    Forum Istanbul          1     20.92
# 99454     Debit Card   2021-03-28         Metrocity          1     20.92
# 99455           Cash   2021-03-16      Istinye Park          1  16800.00
# 99456    Credit Card   2022-10-15  Mall of Istanbul          1    105.57
#
#        Recency
# 0          425
# 1          661
# 2          694
# 3          871
# 4          710
# ...        ...
# 99452      378
# 99453      742
# 99454      920
# 99455      932
# 99456      354
#
# [99457 rows x 13 columns]

# %%
customer_shopping_df.drop_duplicates(subset=["invoice_no"], keep="first", inplace=True)
customer_shopping_df["Frequency"] = 1
display(customer_shopping_df)
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall  Frequency
# 0        Credit Card     5/8/2022            Kanyon          1
# 1         Debit Card   12/12/2021    Forum Istanbul          1
# 2               Cash    9/11/2021         Metrocity          1
# 3        Credit Card   16/05/2021      Metropol AVM          1
# 4               Cash   24/10/2021            Kanyon          1
# ...              ...          ...               ...        ...
# 99452    Credit Card   21/09/2022            Kanyon          1
# 99453           Cash   22/09/2021    Forum Istanbul          1
# 99454     Debit Card   28/03/2021         Metrocity          1
# 99455           Cash   16/03/2021      Istinye Park          1
# 99456    Credit Card   15/10/2022  Mall of Istanbul          1
#
# [99457 rows x 11 columns]

# %%
customer_shopping_df['Monetary'] = customer_shopping_df['quantity'] * customer_shopping_df['price']
display(customer_shopping_df)
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall  Frequency  Monetary
# 0        Credit Card     5/8/2022            Kanyon          1   7502.00
# 1         Debit Card   12/12/2021    Forum Istanbul          1   5401.53
# 2               Cash    9/11/2021         Metrocity          1    300.08
# 3        Credit Card   16/05/2021      Metropol AVM          1  15004.25
# 4               Cash   24/10/2021            Kanyon          1    242.40
# ...              ...          ...               ...        ...       ...
# 99452    Credit Card   21/09/2022            Kanyon          1    293.25
# 99453           Cash   22/09/2021    Forum Istanbul          1     20.92
# 99454     Debit Card   28/03/2021         Metrocity          1     20.92
# 99455           Cash   16/03/2021      Istinye Park          1  16800.00
# 99456    Credit Card   15/10/2022  Mall of Istanbul          1    105.57
#
# [99457 rows x 12 columns]

# %%
customer_shopping_df_rfm = customer_shopping_df[['Recency', 'Frequency','Monetary']]
display(customer_shopping_df_rfm)
# Out:
#        Recency  Frequency  Monetary
# 0          425          1   7502.00
# 1          661          1   5401.53
# 2          694          1    300.08
# 3          871          1  15004.25
# 4          710          1    242.40
# ...        ...        ...       ...
# 99452      378          1    293.25
# 99453      742          1     20.92
# 99454      920          1     20.92
# 99455      932          1  16800.00
# 99456      354          1    105.57
#
# [99457 rows x 3 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
normalization = MinMaxScaler()
rfm_normalization = normalization.fit_transform(customer_shopping_df_rfm)
rfm_normalization = pd.DataFrame(rfm_normalization, columns=customer_shopping_df_rfm.columns)

display(rfm_normalization)
# Out:
#         Recency  Frequency  Monetary
# 0      0.270101        0.0  0.285648
# 1      0.566583        0.0  0.205614
# 2      0.608040        0.0  0.011235
# 3      0.830402        0.0  0.571505
# 4      0.628141        0.0  0.009037
# ...         ...        ...       ...
# 99452  0.211055        0.0  0.010974
# 99453  0.668342        0.0  0.000598
# 99454  0.891960        0.0  0.000598
# 99455  0.907035        0.0  0.639928
# 99456  0.180905        0.0  0.003823
#
# [99457 rows x 3 columns]
